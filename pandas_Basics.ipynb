# %% [markdown]
# # pandas Basics

# %%
import pandas as pd

# %% [markdown]
# ## 1. Create DataFrame

# %%
data = {
    'BlackCoffee': [250, 203, 189, 216, 197], 
    'Latte': [150, 139, 210, 144, 186],
    'ChaiLatte': [143, 182, 166, 172, 102],
    'Mocha': [82, 130, 122, 99, 103],
    'HotChocolate': [87, 90, 95, 119, 107] 
}
purchases = pd.DataFrame(data, index=['June', 'July', 'August', 'September', 'October'])
purchases
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# July               203        182            90    139    130
# August             189        166            95    210    122
# September          216        172           119    144     99
# October            197        102           107    186    103

# %%
purchases.index
# Out:
# Index(['June', 'July', 'August', 'September', 'October'], dtype='object')

# %%
purchases.columns
# Out:
# Index(['BlackCoffee', 'ChaiLatte', 'HotChocolate', 'Latte', 'Mocha'], dtype='object')

# %%
purchases['Latte']
# Out:
# June         150
# July         139
# August       210
# September    144
# October      186
# Name: Latte, dtype: int64

# %%
purchases.loc['September']
# Out:
# BlackCoffee     216
# ChaiLatte       172
# HotChocolate    119
# Latte           144
# Mocha            99
# Name: September, dtype: int64

# %%
purchases.iloc[3]
# Out:
# BlackCoffee     216
# ChaiLatte       172
# HotChocolate    119
# Latte           144
# Mocha            99
# Name: September, dtype: int64

# %%
purchases[1:4]
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# July               203        182            90    139    130
# August             189        166            95    210    122
# September          216        172           119    144     99

# %%
purchases.loc['July':'September']
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# July               203        182            90    139    130
# August             189        166            95    210    122
# September          216        172           119    144     99

# %%
purchases.iloc[1:4]
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# July               203        182            90    139    130
# August             189        166            95    210    122
# September          216        172           119    144     99

# %%
purchases.loc[:, 'BlackCoffee':'HotChocolate']
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate
# June               250        143            87
# July               203        182            90
# August             189        166            95
# September          216        172           119
# October            197        102           107

# %%
purchases.loc['July':'September', 'BlackCoffee':'ChaiLatte']
# Out:
#            BlackCoffee  ChaiLatte
# July               203        182
# August             189        166
# September          216        172

# %%
purchases.iloc[1:4, 0:2]
# Out:
#            BlackCoffee  ChaiLatte
# July               203        182
# August             189        166
# September          216        172

# %%
purchases[purchases['BlackCoffee'] > 200]
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# July               203        182            90    139    130
# September          216        172           119    144     99

# %%
purchases[(purchases['BlackCoffee'] > 200) & (purchases['HotChocolate'] > 100)]
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# September          216        172           119    144     99

# %%
purchases[(purchases['BlackCoffee'] > 200) | (purchases['HotChocolate'] > 100)]
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# July               203        182            90    139    130
# September          216        172           119    144     99
# October            197        102           107    186    103

# %%
purchases.query('BlackCoffee > 200')
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# July               203        182            90    139    130
# September          216        172           119    144     99

# %%
purchases.query('BlackCoffee > 200 & HotChocolate > 100')
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# September          216        172           119    144     99

# %%
purchases.query('BlackCoffee > Mocha * 2')
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# September          216        172           119    144     99

# %% [markdown]
# ## 2. Dealing with more than one DataFrames

# %% [markdown]
# ### A. `pd.concat()`

# %%
df_1 = pd.DataFrame({
    'BlackCoffee': [222, 190, 213, 250, 203],
    'Latte': [198, 178, 157, 150, 139],
    'GreenTeaLatte': [113, 104, 99, 125, 100],
    'WhiteMocha': [130, 142, 110, 102, 106],
    'Espresso': [78, 70, 98, 66, 73]},
    index=['March', 'April', 'May', 'June', 'July'])

df_2 = pd.DataFrame({
    'BlackCoffee': [250, 203, 189, 216, 197], 
    'Latte': [150, 139, 210, 144, 186],
    'ChaiLatte': [143, 182, 166, 172, 102],
    'Mocha': [82, 130, 122, 99, 103],
    'HotChocolate': [87, 90, 95, 119, 107]},
    index=['June', 'July', 'August', 'September', 'October'])

# %%
df_1
# Out:
#        BlackCoffee  Espresso  GreenTeaLatte  Latte  WhiteMocha
# March          222        78            113    198         130
# April          190        70            104    178         142
# May            213        98             99    157         110
# June           250        66            125    150         102
# July           203        73            100    139         106

# %%
df_2
# Out:
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# June               250        143            87    150     82
# July               203        182            90    139    130
# August             189        166            95    210    122
# September          216        172           119    144     99
# October            197        102           107    186    103

# %%
pd.concat([df_1, df_2])
# Out:
#            BlackCoffee  ChaiLatte  Espresso  GreenTeaLatte  HotChocolate  \
# March              222        NaN      78.0          113.0           NaN
# April              190        NaN      70.0          104.0           NaN
# May                213        NaN      98.0           99.0           NaN
# June               250        NaN      66.0          125.0           NaN
# July               203        NaN      73.0          100.0           NaN
# June               250      143.0       NaN            NaN          87.0
# July               203      182.0       NaN            NaN          90.0
# August             189      166.0       NaN            NaN          95.0
# September          216      172.0       NaN            NaN         119.0
# October            197      102.0       NaN            NaN         107.0
#
#            Latte  Mocha  WhiteMocha
# March        198    NaN       130.0
# April        178    NaN       142.0
# May          157    NaN       110.0
# June         150    NaN       102.0
# July         139    NaN       106.0
# June         150   82.0         NaN
# July         139  130.0         NaN
# August       210  122.0         NaN
# September    144   99.0         NaN
# October      186  103.0         NaN

# %%
pd.concat([df_1, df_2], keys=['df_1', 'df_2'])
# Out:
#                 BlackCoffee  ChaiLatte  Espresso  GreenTeaLatte  HotChocolate  \
# df_1 March              222        NaN      78.0          113.0           NaN
#      April              190        NaN      70.0          104.0           NaN
#      May                213        NaN      98.0           99.0           NaN
#      June               250        NaN      66.0          125.0           NaN
#      July               203        NaN      73.0          100.0           NaN
# df_2 June               250      143.0       NaN            NaN          87.0
#      July               203      182.0       NaN            NaN          90.0
#      August             189      166.0       NaN            NaN          95.0
#      September          216      172.0       NaN            NaN         119.0
#      October            197      102.0       NaN            NaN         107.0
#
#                 Latte  Mocha  WhiteMocha
# df_1 March        198    NaN       130.0
#      April        178    NaN       142.0
#      May          157    NaN       110.0
#      June         150    NaN       102.0
#      July         139    NaN       106.0
# df_2 June         150   82.0         NaN
#      July         139  130.0         NaN
#      August       210  122.0         NaN
#      September    144   99.0         NaN
#      October      186  103.0         NaN

# %%
pd.concat([df_1, df_2], join='inner')
# Out:
#            BlackCoffee  Latte
# March              222    198
# April              190    178
# May                213    157
# June               250    150
# July               203    139
# June               250    150
# July               203    139
# August             189    210
# September          216    144
# October            197    186

# %%
pd.concat([df_1, df_2], axis=1)
# Out:
#            BlackCoffee  Espresso  GreenTeaLatte  Latte  WhiteMocha  \
# April            190.0      70.0          104.0  178.0       142.0
# August             NaN       NaN            NaN    NaN         NaN
# July             203.0      73.0          100.0  139.0       106.0
# June             250.0      66.0          125.0  150.0       102.0
# March            222.0      78.0          113.0  198.0       130.0
# May              213.0      98.0           99.0  157.0       110.0
# October            NaN       NaN            NaN    NaN         NaN
# September          NaN       NaN            NaN    NaN         NaN
#
#            BlackCoffee  ChaiLatte  HotChocolate  Latte  Mocha
# April              NaN        NaN           NaN    NaN    NaN
# August           189.0      166.0          95.0  210.0  122.0
# July             203.0      182.0          90.0  139.0  130.0
# June             250.0      143.0          87.0  150.0   82.0
# March              NaN        NaN           NaN    NaN    NaN
# May                NaN        NaN           NaN    NaN    NaN
# October          197.0      102.0         107.0  186.0  103.0
# September        216.0      172.0         119.0  144.0   99.0

# %%
pd.concat([df_1, df_2], join='inner', axis=1)
# Out:
#       BlackCoffee  Espresso  GreenTeaLatte  Latte  WhiteMocha  BlackCoffee  \
# June          250        66            125    150         102          250
# July          203        73            100    139         106          203
#
#       ChaiLatte  HotChocolate  Latte  Mocha
# June        143            87    150     82
# July        182            90    139    130

# %% [markdown]
# ### B. `DataFrame.append()`

# %%
# Same as 'pd.concat([df_1, df_2])'
df_1.append(df_2)
# Out:
#            BlackCoffee  ChaiLatte  Espresso  GreenTeaLatte  HotChocolate  \
# March              222        NaN      78.0          113.0           NaN
# April              190        NaN      70.0          104.0           NaN
# May                213        NaN      98.0           99.0           NaN
# June               250        NaN      66.0          125.0           NaN
# July               203        NaN      73.0          100.0           NaN
# June               250      143.0       NaN            NaN          87.0
# July               203      182.0       NaN            NaN          90.0
# August             189      166.0       NaN            NaN          95.0
# September          216      172.0       NaN            NaN         119.0
# October            197      102.0       NaN            NaN         107.0
#
#            Latte  Mocha  WhiteMocha
# March        198    NaN       130.0
# April        178    NaN       142.0
# May          157    NaN       110.0
# June         150    NaN       102.0
# July         139    NaN       106.0
# June         150   82.0         NaN
# July         139  130.0         NaN
# August       210  122.0         NaN
# September    144   99.0         NaN
# October      186  103.0         NaN

# %% [markdown]
# ### C. `pd.merge()`

# %%
df_3 = pd.DataFrame({
    'country': ['Japan', 'France', 'USA'],
    'population': [13800000, 2140000, 700000],
    'capital?': ['Yes', 'Yes', 'No']},
    index=['Tokyo', 'Paris', 'Boston'])

# %%
df_4 = pd.DataFrame({
    'country': ['Japan', 'USA', 'Switzerland'],
    'capital?': ['No', 'N', 'No'],
    'language': ['Japanese', 'English', 'French']},
    index=['Kyoto', 'NewYork', 'Geneva'])

# %%
df_3
# Out:
#        capital? country  population
# Tokyo       Yes   Japan    13800000
# Paris       Yes  France     2140000
# Boston       No     USA      700000

# %%
df_4
# Out:
#         capital?      country  language
# Kyoto         No        Japan  Japanese
# NewYork        N          USA   English
# Geneva        No  Switzerland    French

# %%
pd.merge(df_3, df_4, on='country', indicator=True)
# Out:
#   capital?_x country  population capital?_y  language _merge
# 0        Yes   Japan    13800000         No  Japanese   both
# 1         No     USA      700000          N   English   both

# %%
pd.merge(df_3, df_4, on=['country'], how='outer', indicator=True)
# Out:
#   capital?_x      country  population capital?_y  language      _merge
# 0        Yes        Japan  13800000.0         No  Japanese        both
# 1        Yes       France   2140000.0        NaN       NaN   left_only
# 2         No          USA    700000.0          N   English        both
# 3        NaN  Switzerland         NaN         No    French  right_only

# %%
pd.merge(df_3, df_4, on='country', how='left', indicator=True)
# Out:
#   capital?_x country  population capital?_y  language     _merge
# 0        Yes   Japan    13800000         No  Japanese       both
# 1        Yes  France     2140000        NaN       NaN  left_only
# 2         No     USA      700000          N   English       both

# %%
pd.merge(df_3, df_4, on='country', how='right', indicator=True)
# Out:
#   capital?_x      country  population capital?_y  language      _merge
# 0        Yes        Japan  13800000.0         No  Japanese        both
# 1         No          USA    700000.0          N   English        both
# 2        NaN  Switzerland         NaN         No    French  right_only

# %% [markdown]
# ### D. `DataFrame.join()`

# %%
df_5 = pd.DataFrame({
    'name': ['A', 'B', 'C'],
    'email': ['a@sample.com', 'b@sample.com', 'c@sample.com'],
    'gender': ['Male', 'Female', 'Female']},
    index=['User1', 'User2', 'User3'])

# %%
df_6 = pd.DataFrame({
    'age': [27, 22, 31],
    'Number of friends': [290, 310, 480]},
    index=['User1', 'User2', 'User4'])

# %%
df_5
# Out:
#               email  gender name
# User1  a@sample.com    Male    A
# User2  b@sample.com  Female    B
# User3  c@sample.com  Female    C

# %%
df_6
# Out:
#        Number of friends  age
# User1                290   27
# User2                310   22
# User4                480   31

# %%
df_5.join(df_6)
# Out:
#               email  gender name  Number of friends   age
# User1  a@sample.com    Male    A              290.0  27.0
# User2  b@sample.com  Female    B              310.0  22.0
# User3  c@sample.com  Female    C                NaN   NaN

# %%
df_5.join(df_6, how='right')
# Out:
#               email  gender name  Number of friends  age
# User1  a@sample.com    Male    A                290   27
# User2  b@sample.com  Female    B                310   22
# User4           NaN     NaN  NaN                480   31

# %%
df_5.join(df_6, how='inner')
# Out:
#               email  gender name  Number of friends  age
# User1  a@sample.com    Male    A                290   27
# User2  b@sample.com  Female    B                310   22

# %%
df_5.join(df_6, how='outer')
# Out:
#               email  gender name  Number of friends   age
# User1  a@sample.com    Male    A              290.0  27.0
# User2  b@sample.com  Female    B              310.0  22.0
# User3  c@sample.com  Female    C                NaN   NaN
# User4           NaN     NaN  NaN              480.0  31.0
